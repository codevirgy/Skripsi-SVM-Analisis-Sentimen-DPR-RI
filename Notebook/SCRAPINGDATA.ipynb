# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install apify-client pandas openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.2/141.2 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 53.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 27.8 MB/s eta 0:00:00
# ...

# %%
from apify_client import ApifyClient
import pandas as pd

# %%
APIFY_TOKEN = "apify_api_hRuFJct8tscRulkwQHOXxNUitUBqmS07QG7E"

client = ApifyClient(APIFY_TOKEN)

# %%
run_input = {
    "lang": "in",
    "maxItems": 10000,

    "searchTerms": [
        "DPR RI",
        "Dewan Perwakilan Rakyat",
        "kinerja DPR",
        "anggota DPR",
        "DPR Indonesia",
        "percaya DPR",
        "kepercayaan publik DPR",
        "DPR bekerja",
        "kebijakan DPR",
        "DPR merugikan rakyat",
        "DPR membantu rakyat"
    ],

    "filter:replies": False,
    "filter:nativeretweets": False,
    "include:nativeretweets": False,

    "filter:links": False,
    "filter:images": False,
    "filter:videos": False,
    "filter:media": False,

    "filter:mentions": False,
    "filter:hashtags": False,

    "filter:quote": False,

    "filter:news": False,

    "filter:blue_verified": False
}

# %%
run = client.actor("CJdippxWmn9uRfooo").call(
    run_input=run_input
)

print("Dataset ID:", run["defaultDatasetId"])
# Out:
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:L7HdwRDWajiZ8RYdq] -> Status: RUNNING, Message:
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:L7HdwRDWajiZ8RYdq] -> 2026-06-12T05:46:49.210Z ACTOR: Pulling container image of build FsAg9tvxqxfok3E4f from registry.
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:L7HdwRDWajiZ8RYdq] -> 2026-06-12T05:46:49.212Z ACTOR: Creating container.
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:L7HdwRDWajiZ8RYdq] -> 2026-06-12T05:46:49.262Z ACTOR: Starting container.
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:L7HdwRDWajiZ8RYdq] -> 2026-06-12T05:46:49.264Z ACTOR: Running under "LIMITED_PERMISSIONS".
# [apify.twitter-x-data-tweet-scraper-pay-per-result-cheapest runId:L7HdwRDWajiZ8RYdq] -> 2026-06-12T05:46:56.039Z Actor is running on the Apify platform, `disable_browser_sandbox` was changed to True.
# ...

# %%
from apify_client import ApifyClient

client = ApifyClient(" ")

dataset_id = "#eo9hTicNuoqcq6sVT"

items = []

for item in client.dataset(dataset_id).iterate_items():
    items.append(item)

print("Jumlah tweet:", len(items))
# Out:
# ---------------------------------------------------------------------------
# UnauthorizedError                         Traceback (most recent call last)
# /tmp/ipykernel_2026/3972518215.py in <cell line: 0>()
#       7 items = []
#       8
# ----> 9 for item in client.dataset(dataset_id).iterate_items():
#      10     items.append(item)
#      11
#
# /usr/local/lib/python3.12/dist-packages/apify_client/_pagination.py in get_items_iterator(callback, limit, offset, chunk_size)
#      57
#      58     while True:
# ---> 59         current_page = callback(
#      60             limit=_next_page_limit(initial_limit, fetched_items, effective_chunk),
#      61             offset=initial_offset + fetched_items,
#
# /usr/local/lib/python3.12/dist-packages/apify_client/_resource_clients/dataset.py in _callback(limit, offset)
#     273
#     274         def _callback(*, limit: int | None = None, offset: int | None = None) -> DatasetItemsPage:
# --> 275             return self.list_items(
# ...
